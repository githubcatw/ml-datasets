# %% [markdown]
# <a href="https://colab.research.google.com/github/githubcatw/ml-datasets/blob/master/TechCrunch_GPT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup:
#
# 1) Make sure GPU is enabled, go to edit->notebook settings->Hardware Accelerator GPU
#
# 2) Make a copy to your google drive, click on copy to drive in panel

# %% [markdown]
# Note: Colab will reset after 12 hours make sure to save your model checkpoints to google drive around 10-11 hours mark or before, then go to runtime->reset all runtimes. Now copy your train model back into colab and start training again from the previous checkpoint.

# %% [markdown]
# clone and cd into repo, nshepperd's fork https://github.com/nshepperd/gpt-2

# %%
# !git clone https://github.com/nshepperd/gpt-2.git
# Out:
# Cloning into 'gpt-2'...
# remote: Enumerating objects: 297, done.
# remote: Total 297 (delta 0), reused 0 (delta 0), pack-reused 297
# Receiving objects: 100% (297/297), 4.40 MiB | 14.72 MiB/s, done.
# Resolving deltas: 100% (160/160), done.

# %%
cd gpt-2
# Out:
# /content/gpt-2

# %% [markdown]
# Install requirements

# %%
# !pip3 install -r requirements.txt
# Out:
# Collecting fire>=0.1.3 (from -r requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d9/69/faeaae8687f4de0f5973694d02e9d6c3eb827636a009157352d98de1129e/fire-0.2.1.tar.gz (76kB)
#      |████████████████████████████████| 81kB 3.8MB/s
# Collecting regex==2017.4.5 (from -r requirements.txt (line 2))
#   Downloading https://files.pythonhosted.org/packages/36/62/c0c0d762ffd4ffaf39f372eb8561b8d491a11ace5a7884610424a8b40f95/regex-2017.04.05.tar.gz (601kB)
#      |████████████████████████████████| 604kB 10.3MB/s
# Requirement already satisfied: requests==2.21.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (2.21.0)
# Collecting tqdm==4.31.1 (from -r requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/6c/4b/c38b5144cf167c4f52288517436ccafefe9dc01b8d1c190e18a6b154cd4a/tqdm-4.31.1-py2.py3-none-any.whl (48kB)
#      |████████████████████████████████| 51kB 22.6MB/s
# Collecting toposort==1.5 (from -r requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/e9/8a/321cd8ea5f4a22a06e3ba30ef31ec33bea11a3443eeb1d89807640ee6ed4/toposort-1.5-py2.py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fire>=0.1.3->-r requirements.txt (line 1)) (1.12.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.6/dist-packages (from fire>=0.1.3->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (2019.6.16)
# Building wheels for collected packages: fire, regex
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.2.1-py2.py3-none-any.whl size=103527 sha256=77868a90e41b45162dc91e39c9c23589dc26ca900d610ab3c0bb9b6c39af2595
#   Stored in directory: /root/.cache/pip/wheels/31/9c/c0/07b6dc7faf1844bb4688f46b569efe6cafaa2179c95db821da
#   Building wheel for regex (setup.py) ... done
#   Created wheel for regex: filename=regex-2017.4.5-cp36-cp36m-linux_x86_64.whl size=533182 sha256=2f8585c63a0d9117ede75a465319b43c2371479e61d6591778063541f2cefdb0
#   Stored in directory: /root/.cache/pip/wheels/75/07/38/3c16b529d50cb4e0cd3dbc7b75cece8a09c132692c74450b01
# Successfully built fire regex
# Installing collected packages: fire, regex, tqdm, toposort
#   Found existing installation: tqdm 4.28.1
#     Uninstalling tqdm-4.28.1:
#       Successfully uninstalled tqdm-4.28.1
# Successfully installed fire-0.2.1 regex-2017.4.5 toposort-1.5 tqdm-4.31.1

# %% [markdown]
# Mount drive to access google drive for saving and accessing checkpoints later. Have to log in to your google account

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# Download the model data

# %%
# !python3 download_model.py 117M
# Out:
# Fetching checkpoint: 1.00kit [00:00, 1.10Mit/s]
# Fetching encoder.json: 1.04Mit [00:00, 43.5Mit/s]
# Fetching hparams.json: 1.00kit [00:00, 1.17Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:07, 66.8Mit/s]
# Fetching model.ckpt.index: 6.00kit [00:00, 4.76Mit/s]
# Fetching model.ckpt.meta: 472kit [00:00, 55.1Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 52.9Mit/s]

# %%
# !python3 download_model.py 345M

# %% [markdown]
# Set encoding

# %%
# !export PYTHONIOENCODING=UTF-8

# %% [markdown]
# Fetch checkpoints, if you have them saved in google drive

# %%
# !cp -r /content/drive/My\ Drive/checkpoint/ /content/gpt-2/

# %% [markdown]
# Let's get our train on! In this case the file is A Tale of Two Cities (Charles Dickens) from Project Gutenberg. To change the dataset GPT-2 models will fine-tune on, change this URL to another .txt file, and change corresponding part of the next cell. Note that you can use small datasets if you want but you will have to be sure not to run the fine-tuning for too long or you will overfit badly. Roughly, expect interesting results within minutes to hours in the 1-10s of megabyte ballpark, and below this you may want to stop the run early as fine-tuning can be very fast.

# %%
# !wget https://raw.githubusercontent.com/githubcatw/ml-datasets/master/techcrunch.txt
# Out:
# --2019-08-18 15:23:45--  https://raw.githubusercontent.com/githubcatw/ml-datasets/master/techcrunch.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48582 (47K) [text/plain]
# Saving to: ‘techcrunch.txt’
#
# techcrunch.txt      100%[===================>]  47.44K  --.-KB/s    in 0.02s
#
# 2019-08-18 15:23:45 (2.36 MB/s) - ‘techcrunch.txt’ saved [48582/48582]

# %% [markdown]
# Start training, add --model_name '345M' to use 345 model

# %%
# !PYTHONPATH=src ./train.py --dataset /content/gpt-2/techcrunch.txt --model_name '117M'
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0818 15:25:16.257632 140485285447552 deprecation_wrapper.py:119] From /content/gpt-2/src/model.py:147: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# W0818 15:25:16.266279 140485285447552 deprecation_wrapper.py:119] From /content/gpt-2/src/memory_saving_gradients.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0818 15:25:16.347925 140485285447552 deprecation_wrapper.py:119] From ./train.py:87: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0818 15:25:16.348186 140485285447552 deprecation_wrapper.py:119] From ./train.py:90: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-08-18 15:25:16.365815: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-08-18 15:25:16.367456: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1d27100 executing computations on platform Host. Devices:
# 2019-08-18 15:25:16.367505: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-08-18 15:25:16.372884: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-08-18 15:25:16.605659: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-18 15:25:16.606159: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1d26a00 executing computations on platform CUDA. Devices:
# 2019-08-18 15:25:16.606190: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2019-08-18 15:25:16.606467: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-18 15:25:16.606815: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2019-08-18 15:25:16.616072: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-18 15:25:16.810602: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-08-18 15:25:16.897540: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2019-08-18 15:25:16.919688: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2019-08-18 15:25:17.110436: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2019-08-18 15:25:17.231326: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2019-08-18 15:25:17.579389: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-08-18 15:25:17.579628: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-18 15:25:17.580090: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-18 15:25:17.580428: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2019-08-18 15:25:17.587528: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-18 15:25:17.589549: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-08-18 15:25:17.589578: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2019-08-18 15:25:17.589590: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2019-08-18 15:25:17.595259: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-18 15:25:17.595731: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-18 15:25:17.596091: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14202 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# W0818 15:25:17.596823 140485285447552 deprecation_wrapper.py:119] From ./train.py:91: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0818 15:25:22.807586 140485285447552 deprecation.py:323] From /content/gpt-2/src/sample.py:65: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0818 15:25:22.820795 140485285447552 deprecation.py:323] From /content/gpt-2/src/sample.py:16: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0818 15:25:22.822315 140485285447552 deprecation.py:323] From /content/gpt-2/src/sample.py:70: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.random.categorical` instead.
# W0818 15:25:22.831616 140485285447552 deprecation_wrapper.py:119] From ./train.py:120: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0818 15:25:28.281828 140485285447552 deprecation_wrapper.py:119] From ./train.py:143: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0818 15:25:28.284400 140485285447552 deprecation_wrapper.py:119] From ./train.py:146: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# W0818 15:25:28.285150 140485285447552 deprecation_wrapper.py:119] From ./train.py:148: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# W0818 15:25:28.285845 140485285447552 deprecation_wrapper.py:119] From ./train.py:151: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# Loading checkpoint models/117M/model.ckpt
# W0818 15:25:33.966505 140485285447552 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Loading dataset...
# 100% 1/1 [00:00<00:00, 3477.86it/s]
# dataset has 10550 tokens
# Training...
# 2019-08-18 15:25:37.843133: W tensorflow/compiler/jit/mark_for_compilation_pass.cc:1412] (One-time warning): Not using XLA:CPU for cluster because envvar TF_XLA_FLAGS=--tf_xla_cpu_global_jit was not set.  If you want XLA:CPU, either set that envvar, or use experimental_jit_scope to enable XLA:CPU.  To confirm that XLA is active, pass --vmodule=xla_compilation_cache=1 (as a proper command-line flag, not via TF_XLA_FLAGS) or set the envvar XLA_FLAGS=--xla_hlo_profile.
# 2019-08-18 15:25:38.086817: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# [1 | 4.47] loss=3.52 avg=3.52
# [2 | 4.92] loss=3.46 avg=3.49
# [3 | 5.38] loss=3.26 avg=3.41
# [4 | 5.83] loss=3.41 avg=3.41
# [5 | 6.29] loss=3.38 avg=3.41
# [6 | 6.74] loss=3.30 avg=3.39
# [7 | 7.20] loss=3.20 avg=3.36
# [8 | 7.65] loss=3.35 avg=3.36
# [9 | 8.11] loss=3.25 avg=3.35
# [10 | 8.56] loss=3.12 avg=3.32
# [11 | 9.02] loss=3.21 avg=3.31
# [12 | 9.47] loss=3.10 avg=3.29
# [13 | 9.93] loss=3.14 avg=3.28
# [14 | 10.38] loss=3.53 avg=3.30
# [15 | 10.84] loss=3.05 avg=3.28
# [16 | 11.29] loss=3.03 avg=3.26
# [17 | 11.75] loss=2.98 avg=3.25
# [18 | 12.21] loss=2.88 avg=3.22
# [19 | 12.66] loss=2.97 avg=3.21
# [20 | 13.12] loss=3.18 avg=3.21
# [21 | 13.58] loss=2.78 avg=3.19
# [22 | 14.03] loss=2.90 avg=3.17
# [23 | 14.49] loss=3.11 avg=3.17
# [24 | 14.95] loss=2.95 avg=3.16
# [25 | 15.41] loss=2.94 avg=3.15
# [26 | 15.87] loss=2.82 avg=3.13
# [27 | 16.33] loss=2.81 avg=3.12
# [28 | 16.78] loss=2.79 avg=3.11
# [29 | 17.24] loss=2.80 avg=3.09
# [30 | 17.70] loss=2.78 avg=3.08
# [31 | 18.16] loss=3.12 avg=3.08
# [32 | 18.62] loss=2.83 avg=3.07
# [33 | 19.08] loss=2.68 avg=3.06
# [34 | 19.53] loss=2.65 avg=3.05
# [35 | 19.99] loss=2.65 avg=3.03
# [36 | 20.45] loss=2.98 avg=3.03
# [37 | 20.92] loss=2.59 avg=3.02
# [38 | 21.38] loss=2.74 avg=3.01
# [39 | 21.84] loss=2.88 avg=3.00
# [40 | 22.30] loss=2.87 avg=3.00
# [41 | 22.76] loss=3.07 avg=3.00
# [42 | 23.22] loss=2.57 avg=2.99
# [43 | 23.68] loss=2.81 avg=2.98
# [44 | 24.14] loss=2.38 avg=2.97
# [45 | 24.60] loss=2.56 avg=2.96
# [46 | 25.06] loss=2.71 avg=2.95
# [47 | 25.52] loss=2.45 avg=2.94
# [48 | 25.98] loss=2.47 avg=2.92
# [49 | 26.44] loss=2.61 avg=2.92
# [50 | 26.90] loss=2.74 avg=2.91
# [51 | 27.37] loss=2.63 avg=2.90
# [52 | 27.83] loss=2.66 avg=2.90
# [53 | 28.30] loss=2.59 avg=2.89
# [54 | 28.76] loss=2.38 avg=2.88
# [55 | 29.22] loss=2.27 avg=2.86
# [56 | 29.69] loss=2.78 avg=2.86
# [57 | 30.15] loss=2.33 avg=2.85
# [58 | 30.62] loss=2.24 avg=2.84
# [59 | 31.09] loss=2.45 avg=2.83
# [60 | 31.55] loss=2.55 avg=2.82
# [61 | 32.02] loss=2.48 avg=2.81
# [62 | 32.48] loss=2.40 avg=2.81
# [63 | 32.95] loss=2.18 avg=2.79
# [64 | 33.42] loss=2.45 avg=2.79
# [65 | 33.89] loss=2.58 avg=2.78
# [66 | 34.35] loss=3.08 avg=2.79
# [67 | 34.81] loss=2.70 avg=2.79
# [68 | 35.28] loss=2.13 avg=2.77
# [69 | 35.75] loss=2.10 avg=2.76
# [70 | 36.22] loss=2.50 avg=2.75
# [71 | 36.69] loss=2.19 avg=2.74
# [72 | 37.16] loss=2.04 avg=2.73
# [73 | 37.63] loss=2.26 avg=2.72
# [74 | 38.10] loss=2.34 avg=2.71
# [75 | 38.57] loss=2.22 avg=2.70
# [76 | 39.04] loss=1.93 avg=2.69
# [77 | 39.51] loss=1.96 avg=2.68
# [78 | 39.98] loss=2.16 avg=2.67
# [79 | 40.45] loss=2.21 avg=2.66
# [80 | 40.91] loss=2.99 avg=2.66
# [81 | 41.39] loss=2.10 avg=2.65
# [82 | 41.86] loss=2.09 avg=2.64
# [83 | 42.33] loss=1.78 avg=2.63
# [84 | 42.80] loss=2.04 avg=2.62
# [85 | 43.27] loss=2.11 avg=2.61
# [86 | 43.74] loss=1.75 avg=2.59
# [87 | 44.21] loss=1.82 avg=2.58
# [88 | 44.69] loss=1.70 avg=2.57
# [89 | 45.16] loss=1.85 avg=2.55
# [90 | 45.63] loss=2.16 avg=2.55
# [91 | 46.10] loss=2.21 avg=2.54
# [92 | 46.57] loss=2.08 avg=2.53
# [93 | 47.05] loss=1.93 avg=2.52
# [94 | 47.52] loss=1.83 avg=2.51
# [95 | 48.00] loss=1.86 avg=2.50
# [96 | 48.48] loss=1.60 avg=2.49
# [97 | 48.95] loss=1.55 avg=2.47
# [98 | 49.43] loss=1.83 avg=2.46
# [99 | 49.91] loss=1.73 avg=2.45
# Generating samples...
# ======== SAMPLE 1 ========
# ine to bring to life a new type of digital reality system.
# The company, called PicoLens, is working with a team led by graduate student Yihui Li, Ph.D. He spent the summer creating virtual reality headsets that measure the quality and size of objects, according to the Star.
# A pilot team is also set to provide live demos in early 2017.
# PicoLens is similar to Glass, which the company is currently using to process images. But instead of a physical viewer, the company is giving developers a platform to build apps that can be deployed to any device.
# It works like this: A user needs a camera or lens, but he or she wants to see what the wearer is doing. The product is called Glass 2 — and it should get a lot more popular as the technology matures.
# Here's what Glass looks like on the actual device:
# Glass isn't just capable of seeing people. It can also perceive objects around it.
# To get a better sense of where your user is looking, Glass 2 is capable of scanning through the physical world, according to the Star. It can then draw a map of your body to help you make sense of it all.
# As the team at Harvard University calls it, Glass 2 "is the next big frontier in optical and telecommunication engineering."
# Think of Glass as the future of augmented reality — and you might be right.
#
# Priced at just $20, Glass 2 doesn't come with an app, but instead includes an API that allows developers to build fully functional applications. From there — just like Glass — it launches you on the Glass learning journey alongside your friends and families.
# It works like this: A user takes a picture of himself or herself with Glass 2 and sends it to Glass. Glass then scans the image to figure out what should happen next. The software looks for tiny patterns in the air as if it were a line in the sand, takes a picture of the line at a precise angle to help you tell if one can move the other, and converts this to a final figure.
# The company doesn't just have a smartphone-ready platform, it also provides a platform for other kinds of 3D-visualization — a revolution in technology that could change how we do work in the real world.
# Glass promises to become the standard for 3D-modeling apps. In other words, apps that use any kind of physical object to make 3D-modeling happen.
# You can bet that will take a lot less battery life than you're used to getting high-end 3D-modeling software like Sketch or Box to the ready and building something from the ground up.
# If Glass 2 has your needs, it could help revolutionize how companies do 3D-modeling, from building prototypes to shipping them to customers.
# H/T: VentureBeat<|endoftext|>Bryan Fischer is a conservative columnist and co-host of the right-wing Texas radio talk show "KMCA." He has written for mainstreaming circles, including the New York Times, Los Angeles Times and Washington Post.
#
# While the White House has declined to officially name its top policy adviser, former National Security Advisor Michael Flynn, Trump has made it more than clear there are several policy analysts in place.
#
# [Flynn resigns with 'very mixed message' about Russia]
# MOSCOW, March 26 (VOA) — The Trump Administration has created its new national security advisor, Mike Flynn.
#
# Admitting he has not been ready for the job over the past 16 months, White House press secretary Sarah Sanders confirmed to The Washington Post on Tuesday that the former national security adviser is being considered for the position. Flynn returned to public life in February as the White House counsel and spent several weeks in Moscow before becoming national security adviser to President Donald Trump.
#
# Flynn, who has not commented publicly on the post, confirmed to the Post that he met with Michael McFaul, the former top national security adviser for President Barack Obama and 2016 Republican presidential nominee Donald Trump. Flynn also said he was given the impression that the Trump campaign was trying to influence the US general election outcome.
# Flynn has called for a "total and complete shutdown" of Muslims entering the United States and called for an end to all refugee resettlement. He has also said he would appoint a special prosecutor to look into ties between the Trump campaign and Russia.
# In recent days, Trump and senior Russia-focused advisers have been working furiously to frame a narrative to blame both the Kremlin and the Kremlin's efforts in the US for the US election. In the process, the US is also helping to make an argument that could be crucial for the US Supreme Court.
# If confirmed, Flynn would be the fifth former Trump National Security Adviser to leave the administration.
#
# Flynn resigned from his post Tuesday after just over a year on the job amid revelations he had discussed sanctions with a senior Russian official during the campaign.
#
# The full list of top officials who
#
# [100 | 62.58] loss=1.44 avg=2.43
# [101 | 63.06] loss=1.65 avg=2.42
# [102 | 63.54] loss=2.03 avg=2.42
# [103 | 64.02] loss=1.61 avg=2.40
# [104 | 64.50] loss=2.36 avg=2.40
# [105 | 64.98] loss=2.08 avg=2.40
# [106 | 65.46] loss=3.15 avg=2.41
# [107 | 65.94] loss=1.94 avg=2.40
# [108 | 66.42] loss=3.07 avg=2.41
# [109 | 66.90] loss=2.51 avg=2.41
# [110 | 67.38] loss=1.53 avg=2.40
# [111 | 67.87] loss=1.57 avg=2.39
# [112 | 68.34] loss=1.35 avg=2.37
# [113 | 68.83] loss=1.38 avg=2.36
# [114 | 69.31] loss=1.47 avg=2.35
# [115 | 69.80] loss=1.49 avg=2.33
# [116 | 70.28] loss=1.76 avg=2.32
# [117 | 70.76] loss=2.12 avg=2.32
# [118 | 71.25] loss=1.71 avg=2.31
# [119 | 71.74] loss=1.42 avg=2.30
# [120 | 72.23] loss=1.34 avg=2.29
# [121 | 72.71] loss=1.30 avg=2.27
# [122 | 73.20] loss=1.51 avg=2.26
# [123 | 73.68] loss=1.09 avg=2.24
# [124 | 74.17] loss=1.09 avg=2.23
# [125 | 74.65] loss=0.92 avg=2.21
# [126 | 75.14] loss=1.31 avg=2.20
# [127 | 75.63] loss=1.80 avg=2.19
# [128 | 76.12] loss=1.27 avg=2.18
# [129 | 76.61] loss=1.49 avg=2.17
# [130 | 77.10] loss=1.75 avg=2.16
# [131 | 77.59] loss=1.22 avg=2.15
# [132 | 78.08] loss=1.16 avg=2.14
# [133 | 78.57] loss=1.42 avg=2.13
# [134 | 79.06] loss=1.04 avg=2.11
# [135 | 79.55] loss=1.69 avg=2.11
# [136 | 80.04] loss=2.37 avg=2.11
# [137 | 80.53] loss=1.44 avg=2.10
# [138 | 81.02] loss=1.67 avg=2.10
# [139 | 81.51] loss=1.02 avg=2.08
# [140 | 82.00] loss=1.04 avg=2.07
# [141 | 82.50] loss=1.48 avg=2.06
# [142 | 82.99] loss=1.18 avg=2.05
# [143 | 83.49] loss=0.78 avg=2.03
# [144 | 83.98] loss=0.69 avg=2.01
# [145 | 84.47] loss=1.32 avg=2.01
# [146 | 84.96] loss=0.81 avg=1.99
# [147 | 85.46] loss=1.11 avg=1.98
# [148 | 85.95] loss=0.61 avg=1.96
# [149 | 86.45] loss=0.73 avg=1.95
# [150 | 86.94] loss=0.86 avg=1.93
# [151 | 87.43] loss=0.97 avg=1.92
# [152 | 87.93] loss=1.24 avg=1.91
# [153 | 88.43] loss=0.96 avg=1.90
# [154 | 88.92] loss=1.10 avg=1.89
# [155 | 89.42] loss=2.22 avg=1.89
# [156 | 89.92] loss=1.50 avg=1.89
# [157 | 90.41] loss=1.60 avg=1.88
# [158 | 90.91] loss=1.18 avg=1.87
# [159 | 91.41] loss=0.81 avg=1.86
# [160 | 91.91] loss=1.54 avg=1.86
# [161 | 92.40] loss=0.95 avg=1.85
# [162 | 92.91] loss=0.74 avg=1.83
# [163 | 93.41] loss=1.13 avg=1.82
# [164 | 93.91] loss=1.12 avg=1.81
# [165 | 94.42] loss=0.69 avg=1.80
# [166 | 94.91] loss=0.90 avg=1.79
# [167 | 95.42] loss=0.78 avg=1.78
# [168 | 95.92] loss=0.53 avg=1.76
# [169 | 96.42] loss=1.07 avg=1.75
# [170 | 96.92] loss=0.53 avg=1.74
# [171 | 97.43] loss=0.62 avg=1.73
# [172 | 97.94] loss=0.62 avg=1.71
# [173 | 98.45] loss=2.14 avg=1.72
# [174 | 98.96] loss=0.40 avg=1.70
# [175 | 99.47] loss=0.79 avg=1.69
# [176 | 99.98] loss=0.88 avg=1.68
# [177 | 100.49] loss=0.77 avg=1.67
# [178 | 100.99] loss=0.76 avg=1.66
# [179 | 101.50] loss=0.48 avg=1.64
# [180 | 102.00] loss=0.61 avg=1.63
# [181 | 102.50] loss=0.90 avg=1.62
# [182 | 103.01] loss=0.55 avg=1.61
# [183 | 103.52] loss=0.66 avg=1.60
# [184 | 104.03] loss=1.28 avg=1.60
# [185 | 104.53] loss=0.50 avg=1.58
# [186 | 105.03] loss=0.55 avg=1.57
# [187 | 105.54] loss=0.64 avg=1.56
# [188 | 106.04] loss=0.54 avg=1.55
# [189 | 106.54] loss=0.53 avg=1.54
# [190 | 107.05] loss=0.37 avg=1.52
# [191 | 107.55] loss=0.40 avg=1.51
# [192 | 108.05] loss=0.73 avg=1.50
# [193 | 108.55] loss=0.79 avg=1.49
# [194 | 109.06] loss=0.44 avg=1.48
# [195 | 109.56] loss=0.41 avg=1.47
# [196 | 110.05] loss=0.67 avg=1.46
# [197 | 110.56] loss=0.44 avg=1.44
# [198 | 111.05] loss=0.32 avg=1.43
# [199 | 111.55] loss=0.52 avg=1.42
# Generating samples...
# ======== SAMPLE 1 ========
#  applications (Django applications in general). We use a set of Django objects that are set up to do various things for an API response. We use setuptools to give it a go, and setuptools reloads every time we reload an API response. The idea is that an API response with a custom key/value store will always be unique to that particular implementation. Every time your API key or value changes, that key or value will automatically be assigned to that particular object.
# Our custom key/value store then inherits from django.contrib.auth.keys and attributes. We can make this happen by putting our custom keys and values into an array, but before that into an array, we have a set of attributes that we have to pass in our custom Python data type.
# First of all, we do a little bit of setuptools:
# def get_custom_keys ( self , ierspender , value , order ): return ierspender.render() for key in key: return key[:].keys() for order in ierspenders.keys(): iersp[key] = ierp[key] order[key] = ierp[key] return ierp def setuptools_hook ( self , key ): return hook(key, ENV, USENet, EcommerceSource, ** kwargs, )
# Now that we have that up and running, let's get going!
# In our Flask application, we start by creating a new file in our root directory called app.py and create a new file named install.py in the same directory as our app.py:
# from flask2client import Client from datetime import datetime ... from datetime.restriction.daterange import Date
# Now that we have a basic understanding of what a date and time zone looks like, it is time to get using them.
# The goal of this guide is to give you an idea of what a typical day looks like in a given date and time zone. For now, this will be useful for creating custom date and time zone properties and then helping you create custom date and time attributes for your custom datetime class.
# From there, the process of creating and using custom datetimes is the same as it was in the before-bundle version of the project. In this first article, we are going to start out with a simple date and time tree that we can use to create and manage custom datetimes.
# The Dict
# The first thing we are going to do is create a dictionary. Our new class is really just an instance of our Date object. Now, since we have created a new Date , we can now create a new datetime instance of it. We will use this datetime instance to tell our date and time classes what month to expect, what day of the week to expect, etc. We can use any of the attributes on the object to tell it what month to use, and how often to use it.
# Now, before we go any further, let's get a bit more used to Python first. Before we do that, we need to know how to read from the dictionary and what about constants to use in our custom date and time properties.
# The Next Step
# Now that we have a bit more familiar with the language, we are ready to take the next step by taking our date and time class and making our date class our day and time. This is going to be a little bit tricky because we have a lot of day classes, but the fundamental thing is this:
# def get_time ( self , month ): return month [ 0 ] for month in range ( 1 , 3 ): return month [ 0 ][:sub(15)][*] for sub within sub ,
# Now, in order to actually take an hour and return an hour, we need to take an hour class. In other words, in order to take units of a human hair to take an hour, we have to start with an hour. Here is what the hour definition looks like in Python 2.3 (with some minor rework and refactoring to make it more idiomatic):
# class Hour ( object ): """Hour class for program time""" # ... def __init__ ( self , hour ): self . hour = hour self . hour. __name__ = 'hour(s)' # ... class Pint ( object ): """Pint class""" # ... def get_dimensions ( self , y ): """Returns the x and y coordinates of the currently selected level""" # The y-coordinate is a (length in radians) tuple with the level y for offset, and next in [coord], in pairs from -[ - 1.14372872 , - 1.14372895 ] to self . level # ... return self . y-coordinates[indices] for offset in y: if offset[:interval] < 2 : return offset[
#
# [200 | 122.68] loss=0.38 avg=1.41
# [201 | 123.18] loss=0.33 avg=1.40
# [202 | 123.67] loss=0.37 avg=1.39
# [203 | 124.17] loss=0.55 avg=1.38
# [204 | 124.67] loss=0.38 avg=1.36
# [205 | 125.16] loss=0.35 avg=1.35
# [206 | 125.65] loss=0.65 avg=1.34
# [207 | 126.15] loss=0.46 avg=1.33
# [208 | 126.64] loss=0.28 avg=1.32
# [209 | 127.13] loss=0.40 avg=1.31
# [210 | 127.61] loss=0.25 avg=1.30
# [211 | 128.10] loss=1.72 avg=1.30
# [212 | 128.59] loss=0.31 avg=1.29
# [213 | 129.08] loss=0.38 avg=1.28
# [214 | 129.57] loss=0.87 avg=1.28
# [215 | 130.06] loss=0.25 avg=1.27
# [216 | 130.55] loss=0.30 avg=1.26
# [217 | 131.04] loss=0.27 avg=1.24
# [218 | 131.53] loss=0.28 avg=1.23
# [219 | 132.02] loss=0.40 avg=1.22
# [220 | 132.51] loss=0.21 avg=1.21
# [221 | 133.00] loss=0.49 avg=1.20
# [222 | 133.49] loss=0.30 avg=1.19
# [223 | 133.97] loss=0.27 avg=1.18
# [224 | 134.46] loss=0.64 avg=1.18
# [225 | 134.95] loss=0.33 avg=1.17
# [226 | 135.44] loss=0.43 avg=1.16
# [227 | 135.93] loss=0.19 avg=1.15
# [228 | 136.42] loss=0.24 avg=1.14
# [229 | 136.91] loss=0.22 avg=1.13
# [230 | 137.40] loss=0.27 avg=1.12
# [231 | 137.89] loss=0.23 avg=1.11
# [232 | 138.38] loss=0.23 avg=1.10
# [233 | 138.87] loss=0.85 avg=1.10
# [234 | 139.36] loss=0.15 avg=1.09
# [235 | 139.84] loss=0.34 avg=1.08
# [236 | 140.34] loss=0.32 avg=1.07
# [237 | 140.82] loss=0.23 avg=1.06
# [238 | 141.31] loss=0.23 avg=1.05
# [239 | 141.80] loss=0.22 avg=1.04
# [240 | 142.29] loss=0.26 avg=1.03
# [241 | 142.78] loss=0.15 avg=1.02
# [242 | 143.27] loss=0.18 avg=1.01
# [243 | 143.76] loss=0.24 avg=1.01
# [244 | 144.25] loss=0.21 avg=1.00
# [245 | 144.74] loss=0.18 avg=0.99
# [246 | 145.23] loss=0.43 avg=0.98
# [247 | 145.72] loss=0.15 avg=0.97
# [248 | 146.21] loss=0.36 avg=0.97
# [249 | 146.70] loss=0.36 avg=0.96
# [250 | 147.19] loss=0.25 avg=0.95
# [251 | 147.67] loss=0.27 avg=0.95
# [252 | 148.16] loss=0.24 avg=0.94
# [253 | 148.65] loss=0.36 avg=0.93
# [254 | 149.14] loss=0.19 avg=0.92
# [255 | 149.63] loss=0.41 avg=0.92
# [256 | 150.12] loss=0.24 avg=0.91
# [257 | 150.61] loss=0.85 avg=0.91
# [258 | 151.10] loss=0.16 avg=0.90
# [259 | 151.59] loss=0.78 avg=0.90
# [260 | 152.08] loss=0.28 avg=0.89
# [261 | 152.56] loss=0.18 avg=0.89
# [262 | 153.06] loss=0.16 avg=0.88
# [263 | 153.54] loss=0.17 avg=0.87
# [264 | 154.03] loss=0.53 avg=0.87
# [265 | 154.52] loss=0.19 avg=0.86
# [266 | 155.01] loss=0.16 avg=0.85
# [267 | 155.50] loss=0.21 avg=0.85
# [268 | 155.98] loss=0.47 avg=0.84
# [269 | 156.47] loss=0.16 avg=0.83
# [270 | 156.96] loss=0.10 avg=0.83
# [271 | 157.45] loss=0.13 avg=0.82
# [272 | 157.94] loss=0.25 avg=0.81
# [273 | 158.43] loss=0.32 avg=0.81
# [274 | 158.92] loss=0.14 avg=0.80
# [275 | 159.41] loss=0.13 avg=0.79
# [276 | 159.90] loss=0.21 avg=0.79
# [277 | 160.39] loss=0.17 avg=0.78
# [278 | 160.88] loss=0.22 avg=0.77
# [279 | 161.37] loss=0.16 avg=0.77
# [280 | 161.86] loss=0.13 avg=0.76
# [281 | 162.35] loss=0.15 avg=0.75
# [282 | 162.84] loss=0.17 avg=0.75
# [283 | 163.32] loss=0.54 avg=0.75
# [284 | 163.81] loss=0.13 avg=0.74
# [285 | 164.30] loss=0.16 avg=0.73
# [286 | 164.79] loss=0.16 avg=0.73
# [287 | 165.28] loss=0.10 avg=0.72
# [288 | 165.77] loss=0.25 avg=0.72
# [289 | 166.26] loss=0.19 avg=0.71
# [290 | 166.74] loss=0.14 avg=0.70
# [291 | 167.24] loss=0.12 avg=0.70
# [292 | 167.73] loss=0.13 avg=0.69
# [293 | 168.21] loss=0.29 avg=0.69
# [294 | 168.70] loss=0.09 avg=0.68
# [295 | 169.19] loss=0.08 avg=0.68
# [296 | 169.68] loss=0.09 avg=0.67
# [297 | 170.17] loss=0.15 avg=0.66
# [298 | 170.66] loss=0.12 avg=0.66
# [299 | 171.15] loss=0.18 avg=0.65
# Generating samples...
# ======== SAMPLE 1 ========
#  glasses.
# So what can you do to make your smartphone more energy-efficient? Well, there are a couple of things. The first is to buy a better battery pack. That may sound like a no-brainer at first, but research shows that really doesn't help the batteries of the most vulnerable people in their lives. In fact, research from Stanford shows that taking out a student loan can have an immediate financial impact.
# In the latest data from the Stanford Energy Institute, we looked at median interest payments on a variety of high-interest loans in the United States and calculated the percentage change in monthly variable interest amounts. We did that by taking into account both the average monthly repayment amount and the interest rate at the end of the term. Here are the average monthly payments for all 50 states and the District of Columbia:
# Student loan repayments increase with income
# Student loan repayments decrease with wealth
# Student loan interest payments increase with job loss
# Here are the top 5% on average hardest off for borrowers with student loans:
# Student loan interest payments increase with income
# Student loan repayments decrease with big money at work
# Student loan interest payments increase with house prices going up
# Student loan interest payments increase with car loans going away
# Student loan interest payments increase with student loans going on expiring bills — Justin Sullivan /Getty Images
# As a rule of thumb, earning a little more per month than you are now is good enough, but getting by if you only make small amounts a day could make a big difference.
# Here are some ways to make a bigger impact.
# The One Belt, One Net
# Most Americans — whether they or their children are growing up without a mobility device — are ignorant of the unintended economic and social costs of using technology.
# According to a recent report by the International Monetary Fund, more than three in four adults in the Holy Land Islands are now without a income, and more than three quarters of U.S. adults are without a college degree.
# For many backpackers, the journey to new cities brings with it a host of economic and social costs.
# For one, the often unaffordable landmass can't support its massive population — and often physically taxing transportation option — which can often take up to 30 days.
# For another, the often volatile weather known to toaders is often associated with disease, and in some cases, arson.
# For many backpackers, moving to the new cities brought with it a host of economic and social costs.
# For example, many backpackers turn to alcohol to get around — often to the trouble of getting around — and to recharge batteries or electronics.
# For many, moving to the new cities brought with it a host of health and economic benefits. For one, the experience of using a technology to improve health was very similar to that of moving to a new city, experts say . . . assuming for a second.
# The solution, according to the IMF, is to "look at existing international health and safety regulations and make a determination based on the benefit to the jurisdiction at the economic, social and cultural level."
# Here are a few examples of how the report would apply to the U.K.:
# New taxes on alcohol — especially for new markets and craft brew pubs — could be a big help. Without those sorts of taxes, it's difficult to envision anyone expecting to be harmful to others.
# New capital gains and losses regulations could also be a big help. Moving to the new countries led to some levies being higher than originally planned, which could be beneficial for business growth in those regions, the report says.
# For now, though, the focus is on the economic — and social — benefits of the new taxes.
# For now, the focus is on the economic — and social — benefits of the new taxes. For now, the tax rules are the same as they were a year ago, when the report was first published. But for high-income households, the changes are even more sweeping.
# For now, the tax rules for properties with more than $1 million in market value will be the same as they were a year ago. But for multi-family structures with more than $1 million in market value, the structures will still be taxed at a higher rate than they are now: 5.5%, assuming the structures sell out within 12 months of purchase.
# For properties with less than $1 million in market value, the rates will also be higher.
# For properties with more than $1 million in market value, the rates will continue to be 2.75%, with an additional 2%.
# For properties with more than $1 million in market value, the rates will be 3.5%, with an additional 2%.
# For properties with less than $1 million in market value, the rates will be 4%, with an additional 8%.
# For properties with more than $1 million in market value, the rates will continue to be 8%, with an additional 21%.
# For properties with more than $1 million in market value, the rates increase
#
# [300 | 182.29] loss=0.14 avg=0.65
# [301 | 182.78] loss=0.19 avg=0.64
# [302 | 183.28] loss=0.16 avg=0.64
# [303 | 183.77] loss=0.24 avg=0.63
# [304 | 184.27] loss=0.31 avg=0.63
# [305 | 184.77] loss=0.13 avg=0.62
# [306 | 185.27] loss=0.19 avg=0.62
# [307 | 185.76] loss=0.10 avg=0.61
# [308 | 186.26] loss=0.15 avg=0.61
# [309 | 186.75] loss=0.23 avg=0.61
# [310 | 187.25] loss=0.11 avg=0.60
# [311 | 187.74] loss=0.08 avg=0.60
# [312 | 188.23] loss=0.15 avg=0.59
# [313 | 188.73] loss=0.08 avg=0.59
# [314 | 189.22] loss=0.12 avg=0.58
# [315 | 189.72] loss=0.12 avg=0.58
# [316 | 190.21] loss=0.10 avg=0.57
# [317 | 190.70] loss=0.09 avg=0.57
# [318 | 191.20] loss=0.14 avg=0.56
# [319 | 191.69] loss=0.10 avg=0.56
# [320 | 192.19] loss=0.15 avg=0.55
# [321 | 192.68] loss=0.12 avg=0.55
# [322 | 193.18] loss=0.14 avg=0.54
# [323 | 193.67] loss=0.20 avg=0.54
# [324 | 194.16] loss=0.10 avg=0.54
# [325 | 194.66] loss=0.22 avg=0.53
# [326 | 195.15] loss=0.15 avg=0.53
# [327 | 195.65] loss=0.08 avg=0.52
# [328 | 196.14] loss=0.11 avg=0.52
# [329 | 196.63] loss=0.24 avg=0.52
# [330 | 197.13] loss=0.19 avg=0.51
# [331 | 197.62] loss=0.18 avg=0.51
# [332 | 198.11] loss=0.11 avg=0.51
# [333 | 198.61] loss=0.13 avg=0.50
# [334 | 199.10] loss=0.10 avg=0.50
# [335 | 199.59] loss=0.09 avg=0.49
# [336 | 200.08] loss=0.13 avg=0.49
# [337 | 200.57] loss=0.08 avg=0.48
# [338 | 201.07] loss=0.12 avg=0.48
# [339 | 201.56] loss=0.09 avg=0.48
# [340 | 202.05] loss=0.07 avg=0.47
# [341 | 202.54] loss=0.10 avg=0.47
# [342 | 203.03] loss=0.11 avg=0.47
# [343 | 203.53] loss=0.92 avg=0.47
# [344 | 204.02] loss=0.09 avg=0.47
# [345 | 204.52] loss=0.11 avg=0.46
# [346 | 205.01] loss=0.21 avg=0.46
# [347 | 205.50] loss=0.13 avg=0.46
# [348 | 205.99] loss=0.09 avg=0.45
# [349 | 206.48] loss=0.12 avg=0.45
# [350 | 206.98] loss=0.10 avg=0.45
# [351 | 207.47] loss=0.12 avg=0.44
# [352 | 207.96] loss=0.13 avg=0.44
# [353 | 208.45] loss=0.11 avg=0.44
# [354 | 208.94] loss=0.10 avg=0.43
# [355 | 209.43] loss=0.06 avg=0.43
# [356 | 209.92] loss=0.34 avg=0.43
# [357 | 210.41] loss=0.10 avg=0.42
# [358 | 210.90] loss=0.08 avg=0.42
# [359 | 211.39] loss=0.07 avg=0.42
# [360 | 211.88] loss=0.06 avg=0.41
# [361 | 212.38] loss=0.09 avg=0.41
# [362 | 212.87] loss=0.07 avg=0.41
# [363 | 213.36] loss=0.13 avg=0.40
# [364 | 213.85] loss=0.14 avg=0.40
# [365 | 214.34] loss=0.12 avg=0.40
# [366 | 214.83] loss=0.14 avg=0.40
# [367 | 215.32] loss=0.12 avg=0.39
# [368 | 215.82] loss=0.09 avg=0.39
# [369 | 216.31] loss=0.13 avg=0.39
# [370 | 216.80] loss=0.12 avg=0.38
# [371 | 217.29] loss=0.10 avg=0.38
# [372 | 217.78] loss=0.12 avg=0.38
# [373 | 218.27] loss=0.14 avg=0.38
# [374 | 218.76] loss=0.07 avg=0.37
# [375 | 219.25] loss=0.09 avg=0.37
# [376 | 219.74] loss=0.15 avg=0.37
# [377 | 220.23] loss=0.11 avg=0.36
# [378 | 220.72] loss=0.10 avg=0.36
# [379 | 221.21] loss=0.12 avg=0.36
# [380 | 221.70] loss=0.13 avg=0.36
# [381 | 222.19] loss=0.10 avg=0.35
# [382 | 222.68] loss=0.07 avg=0.35
# [383 | 223.17] loss=0.11 avg=0.35
# [384 | 223.66] loss=0.14 avg=0.35
# [385 | 224.15] loss=0.08 avg=0.34
# [386 | 224.64] loss=0.11 avg=0.34
# [387 | 225.13] loss=0.10 avg=0.34
# [388 | 225.62] loss=0.09 avg=0.34
# [389 | 226.11] loss=0.05 avg=0.33
# [390 | 226.59] loss=0.05 avg=0.33
# [391 | 227.08] loss=0.10 avg=0.33
# [392 | 227.57] loss=0.08 avg=0.33
# [393 | 228.06] loss=0.08 avg=0.32
# [394 | 228.56] loss=0.11 avg=0.32
# [395 | 229.04] loss=0.60 avg=0.32
# [396 | 229.53] loss=0.13 avg=0.32
# [397 | 230.02] loss=0.10 avg=0.32
# [398 | 230.51] loss=0.08 avg=0.32
# [399 | 231.00] loss=0.09 avg=0.32
# Generating samples...
# ======== SAMPLE 1 ========
#  borrowers.
# From there, they could move on to another business, one that was more focused on shipping. Or they could pursue a doctor-patient dyad, in which a startup cohort is brought in to make the rounds but does not take into account gender, income, and other characteristics of the the the theta-strapped parties.
# The Binks team, in fact, has pivoted to focus this summer on taking off and running companies that deliver. Here, she tells TechCrunch, ╡ build from the╡ deck:
# We want to be the startup incubator for the next generation of startups. We want to be where the next generation of startups go about what they do, where They’s business is made possible, by us,╙ [founders] Kleiner Perkins and American Express.
# We are bringing the power of data to the next level by making it possible for startups to go about making decisions around data — their own destiny. This includes making the right choices for the right customers.”
# TechCrunch has the details about the show; which startups are currently on look to join the Binks Clover Team; whether that’s a domestic production company joining in the expansion; what startups can expect when Binks Clover expands to Hong Kong in the future (we got a bit more details on that at this year’ party …); what startups can expect in-app purchases, teamsives, loyalty programs, pegging, msd, Re/Code, Grallo, 5Ten and more; what’s making the companyest deals this month, and how those stack up against the USD, GBP and SD prices
# For now, though, the only change is that the Buddhabro team is introducing a series of tests.
# Bedinks is shaping up pretty much the same way as it did just three weeks ago; by using light sensors strapped to cars, the Buddhabro teams have turned around a Range Rover Verne 1A87M into a capable emissions-monitoring car with a little help from autonomous driving.
# The startup, which has raised $18 million in seed funding, was founded as a lab for genetically engineered ingredients manufacturing, but has morphed into one big time with startup kit — with a mission to make the next generation of car-changer technology accessible to the masses.
# "With the right investors, we’m seriously going to the moon," co-founder Kostya Shysh tells TechCrunch.
# Aside from coming up with a strategy that combines the assistance of a car's accelerator and airbag with a software suite, Shysh’s most recent batch of software includes a for–the-future clause that lets the company avoid the pitfalls of technology acquisition.
# That’s why the co-working title Bedtime Stories is headed up by ―Foundation’s Tero Lai and Hongxing Gao, “founders of “Foundation Capital」.
# Led by Tero,’ the “New York–based entrepreneur, they are’t here shaping the future of automotive mobility.
#
# Beside automaking, the Foundation consists of “FitzGo®, “italia®, and four‐wheel drive urs: Tesla® and Model3’s, which are also based on Tesla's now‑defunct but highly successful but less-than‑stellar Model S and Model X.
# With production set to begin in the fall, what is currently considered a certainty for the Model 3 will be scrap by the end of the year, with little or no service level scaling considered. While the future of mobility in the U.S. looks bright for now, there is a bright future ahead for mobility solutions at large, says co-founder and CTO Tero Li.
# “From a functional perspective, “the only technology platform capable of realistically scaling to the next level is the one at the hardware level. “ There is nothing more empowering than finding the right solution for you and the planet, and then using that to your benefit.“
# All but a prototype of the the new the’s Dior and Fluxx mobility set-ups is set for deployment, with a second Dior showing set to soon be upon the class-A engineer.
# Though the future look and feel of mobility already looks promising right now, Li says the next generation of capable mobility devices are looking impressive.
# "It’s crazy powerful. It’s the fastest growing technology in the world. It also has the lowest energy density. Let’s face it, a backpack filled with electronics will never feel as comfortable as a backpack that has this big [elemental system]," says the the’slammering FromB’d engineer.
# For the current generation of tech companies, FromB provides free unicorns training soon-to-be grandmas with a functioning jaw
#
# [400 | 242.18] loss=0.07 avg=0.31
# [401 | 242.68] loss=0.11 avg=0.31
# [402 | 243.17] loss=0.09 avg=0.31
# [403 | 243.66] loss=0.07 avg=0.31
# [404 | 244.16] loss=0.07 avg=0.30
# [405 | 244.65] loss=0.10 avg=0.30
# [406 | 245.14] loss=0.09 avg=0.30
# [407 | 245.64] loss=0.09 avg=0.30
# [408 | 246.13] loss=0.10 avg=0.30
# [409 | 246.62] loss=0.05 avg=0.29
# [410 | 247.11] loss=0.08 avg=0.29
# [411 | 247.60] loss=0.09 avg=0.29
# [412 | 248.09] loss=0.06 avg=0.29
# [413 | 248.58] loss=0.70 avg=0.29
# [414 | 249.07] loss=0.07 avg=0.29
# [415 | 249.56] loss=0.09 avg=0.29
# [416 | 250.05] loss=0.06 avg=0.28
# [417 | 250.54] loss=0.05 avg=0.28
# [418 | 251.03] loss=0.10 avg=0.28
# [419 | 251.53] loss=0.09 avg=0.28
# [420 | 252.02] loss=0.10 avg=0.28
# [421 | 252.51] loss=0.10 avg=0.27
# [422 | 253.01] loss=0.08 avg=0.27
# [423 | 253.50] loss=0.10 avg=0.27
# [424 | 253.99] loss=0.08 avg=0.27
# [425 | 254.48] loss=0.12 avg=0.27
# [426 | 254.97] loss=0.10 avg=0.27
# [427 | 255.46] loss=0.08 avg=0.26
# [428 | 255.96] loss=0.06 avg=0.26
# [429 | 256.45] loss=0.08 avg=0.26
# [430 | 256.95] loss=0.05 avg=0.26
# [431 | 257.44] loss=0.05 avg=0.26
# [432 | 257.93] loss=0.17 avg=0.25
# [433 | 258.42] loss=0.09 avg=0.25
# [434 | 258.91] loss=0.09 avg=0.25
# [435 | 259.40] loss=0.07 avg=0.25
# [436 | 259.89] loss=0.10 avg=0.25
# [437 | 260.38] loss=0.06 avg=0.25
# [438 | 260.87] loss=0.05 avg=0.24
# [439 | 261.36] loss=0.06 avg=0.24
# [440 | 261.85] loss=0.08 avg=0.24
# [441 | 262.34] loss=0.10 avg=0.24
# [442 | 262.83] loss=0.09 avg=0.24
# [443 | 263.32] loss=0.06 avg=0.24
# [444 | 263.81] loss=0.10 avg=0.23
# [445 | 264.30] loss=0.09 avg=0.23
# [446 | 264.79] loss=0.21 avg=0.23
# [447 | 265.28] loss=0.07 avg=0.23
# [448 | 265.77] loss=0.11 avg=0.23
# [449 | 266.27] loss=0.08 avg=0.23
# [450 | 266.76] loss=0.07 avg=0.23
# [451 | 267.25] loss=0.05 avg=0.22
# [452 | 267.75] loss=0.13 avg=0.22
# [453 | 268.24] loss=0.09 avg=0.22
# [454 | 268.73] loss=0.15 avg=0.22
# [455 | 269.22] loss=0.09 avg=0.22
# [456 | 269.71] loss=0.09 avg=0.22
# [457 | 270.20] loss=0.10 avg=0.22
# [458 | 270.70] loss=0.10 avg=0.22
# [459 | 271.19] loss=0.11 avg=0.22
# [460 | 271.68] loss=0.07 avg=0.21
# [461 | 272.17] loss=0.07 avg=0.21
# [462 | 272.66] loss=0.06 avg=0.21
# [463 | 273.15] loss=0.07 avg=0.21
# [464 | 273.64] loss=0.15 avg=0.21
# [465 | 274.13] loss=0.09 avg=0.21
# [466 | 274.63] loss=0.09 avg=0.21
# [467 | 275.12] loss=0.06 avg=0.21
# [468 | 275.61] loss=0.05 avg=0.20
# [469 | 276.11] loss=0.07 avg=0.20
# [470 | 276.60] loss=0.06 avg=0.20
# [471 | 277.09] loss=0.08 avg=0.20
# [472 | 277.57] loss=0.14 avg=0.20
# [473 | 278.06] loss=0.11 avg=0.20
# [474 | 278.55] loss=0.11 avg=0.20
# [475 | 279.04] loss=0.30 avg=0.20
# [476 | 279.53] loss=0.07 avg=0.20
# [477 | 280.02] loss=0.07 avg=0.20
# [478 | 280.51] loss=0.09 avg=0.19
# [479 | 281.00] loss=0.13 avg=0.19
# [480 | 281.49] loss=0.11 avg=0.19
# [481 | 281.98] loss=0.08 avg=0.19
# [482 | 282.47] loss=0.08 avg=0.19
# [483 | 282.96] loss=0.06 avg=0.19
# [484 | 283.45] loss=0.05 avg=0.19
# [485 | 283.95] loss=0.06 avg=0.19
# [486 | 284.44] loss=0.08 avg=0.19
# [487 | 284.93] loss=0.07 avg=0.18
# [488 | 285.42] loss=0.05 avg=0.18
# [489 | 285.91] loss=0.07 avg=0.18
# [490 | 286.40] loss=0.09 avg=0.18
# [491 | 286.89] loss=0.05 avg=0.18
# [492 | 287.38] loss=0.06 avg=0.18
# [493 | 287.87] loss=0.07 avg=0.18
# [494 | 288.36] loss=0.39 avg=0.18
# [495 | 288.85] loss=0.10 avg=0.18
# [496 | 289.34] loss=0.08 avg=0.18
# [497 | 289.83] loss=0.07 avg=0.18
# [498 | 290.31] loss=0.08 avg=0.18
# [499 | 290.80] loss=0.05 avg=0.17
# Generating samples...
# ======== SAMPLE 1 ========
#  to be a bit tricky to detect, because the instrument doesn
# ’t have a GPS or a scanner yet. It’s just a smartphone, and it does a lot of different things,
# “it’s able to detect the
# pulse of a
# pulse, it can read
# intercepts through sweat, it’s able to read
# bloodflow characteristics, and it
# poresfill test it’s able to fill. It’s about $300.
# ’
# A survey by the University of Texas School of Medicine found that 40% of Texas students and women said they used alcohol
# as a
# prophecy or ansuffrage month-round, compared to 36% of women aged 18-29
# A survey of 1,000 Texas high school seniors found that nearly one out of ten (penalties included at the polls)
# were because a student had an affair with
# a first or second
# studentteacher. For the remainder, the survey found, students were more likely to
# involved themselves
# alone than
# with other students, with one student
# found at fault for a sorority house party and the
# other
# involved in a failed
# relationship<|endoftext|>The second quarter of last year saw the launch of a brand-new brand of guns that passed stringent background checks. Texas banned military-style assault weapons and replaced them with semi-automatic rifles. Now, with Senate Bill 1232, the Lone Star State is giving law enforcement more leeway to deal with the dangerous and untrained.
# In addition to banning the public from the streets of the Lone Star State, the Senate bill would also allow Texas sheriffs to issue concealed weapons licenses to people found not to have a criminal record, a policy that Texas and Washington D.C. have seen with similar laws.
# In a statement to FOX 26, Sen. Joe Manchin (D-W.Va.) said, "The Department of Justice has demonstrated it can and must do more to protect our people and communities from violent extremists. This bill sends a strong signal that we are committed to building on our resolve to ensure every Texas family has the utmost security."
# The existing Texas law allows the state and Washington with little or no cooperation with the business of taking people's guns away. The new Texas law requires that private sales of semi-automatic rifles and assault-command systems, along with certain licensed carry reciprocity programs, with a manufacturer's current model and up, are certain laws.
#
# The Texas Military Businessman's Alliance, a Washington-based trade group, led by secretary of state Kysen Reynolds, sponsored the bill.
# While the military has seen its stock increase as more people move to cities to defend their property, the Texas military hasn’t seen its stock increase as quickly as the other way. In 2017, the Texas Department of Defense contracted with 521 K-12 unit to 5 position models, and in total, 252 of those K-12s received the state-approved assault weapons license.
# In addition to the license, the 521 Texasassault weapons are a Desert Eagle, Desert Eagle Cover and Desert Assault Scope.
# A replacement is planned forherent with the addition of a physical with K-12 leaders.
# “The candidates for the Texasassault license are as follows”
# LAURA PAGLO, HOST:
#
# Defense Secretary James Mattis today said the United States is prepared to protect itself from the kinds of terrorist threats facing our allies and partners in the Middle East and beyond.
#
# “We will make it absolutely clear and frankly say it is time for the U.S. military to be held to a higher standard. The American people deserve to have the highest level of command at all times, and we must have a commander-in-chief who is taking the lead in ensuring that happens.
# PAGLO: U.S. military leaders joined United Nations chief Antonio Guterres last week in Geneva for his latest round of global dialogue building. The two met in good spirits, with some visiting the Asian superpower for a chance to reaffirm Washington's commitment to multilateral development.
# Lukas Richmond, Author, New York Times bestselling, and TechCrunch Senior Editor, spent three years as a Red Zone tour guide for the leading U.S. hotel chains.
# Virginia Tech product Richmond spent the summer at the center of a fierce lobbying battle with New York-based First Look Capital, where she says the two companies have a history of harassment.
# San Francisco-based First Look recently spent more than a year attempting to reach out to chief executive officer and its CEO to no response. In a recent conference call, First Look CEO Elbridge Lara declined to discuss the current state of the company.
#
# “We continue to have questions that we are still having to address and we always want to answer that quickly, but” Lara said.
#
# In addition to operating nationwide, the company is also a subsidiary of Virgin
#
# [500 | 302.03] loss=0.09 avg=0.17
# [501 | 302.52] loss=0.06 avg=0.17
# [502 | 303.01] loss=0.07 avg=0.17
# [503 | 303.51] loss=0.12 avg=0.17
# [504 | 304.00] loss=0.07 avg=0.17
# [505 | 304.49] loss=0.08 avg=0.17
# [506 | 304.98] loss=0.10 avg=0.17
# [507 | 305.48] loss=0.12 avg=0.17
# ...
# [873 | 517.39] loss=0.03 avg=0.06
# [874 | 517.88] loss=0.06 avg=0.06
# [875 | 518.37] loss=0.05 avg=0.06
# [876 | 518.86] loss=0.06 avg=0.06
# [877 | 519.35] loss=0.04 avg=0.06
# [878 | 519.83] loss=0.03 avg=0.06
# [879 | 520.33] loss=0.06 avg=0.06
# [880 | 520.82] loss=0.05 avg=0.06
# [881 | 521.31] loss=0.05 avg=0.06
# [882 | 521.80] loss=0.04 avg=0.06
# [883 | 522.29] loss=0.04 avg=0.06
# [884 | 522.79] loss=0.05 avg=0.06
# [885 | 523.28] loss=0.05 avg=0.06
# [886 | 523.78] loss=0.04 avg=0.06
# [887 | 524.27] loss=0.12 avg=0.06
# [888 | 524.76] loss=0.04 avg=0.06
# [889 | 525.25] loss=0.04 avg=0.06
# [890 | 525.74] loss=0.05 avg=0.06
# [891 | 526.23] loss=0.04 avg=0.06
# [892 | 526.72] loss=0.04 avg=0.06
# [893 | 527.21] loss=0.03 avg=0.06
# [894 | 527.70] loss=0.05 avg=0.06
# [895 | 528.19] loss=0.07 avg=0.06
# [896 | 528.68] loss=0.04 avg=0.06
# [897 | 529.17] loss=0.05 avg=0.06
# [898 | 529.66] loss=0.05 avg=0.06
# [899 | 530.15] loss=0.04 avg=0.06
# Generating samples...
# ======== SAMPLE 1 ========
#  their patients are more likely to be women’surgical’ women’srologers,” explains David Bongiovanni, an associate professor of obstetrics and gynecology at New York University. The city’s emergency room is more often populated by women who are in primary or preventive medicine, and women who are in surgical centers.
# To address this, Bogdan tells TechCrunch she created the first ­universal referral network (UGC) to encourage women to sexualize their genitalia online. The network uses magnetic sensors to detect the movement of a user's bra and panties, and its cameras snap a digital radar device that identifies the user by looking at its two-dimensional images. The network’s images can then be broadcast to hundreds of millions of people around the world.
# Founded in 2012 by A.K. Pulkkinen at his New York-based startup Immersive Computing, ABF currently has a location-aware design in its Armstrong, Massachusetts, headquarters. The company plans to open another location-aware tech plant in the city’s Fulton County.
#
# [Image: Gabrielle Corbin/CNET]
#
# [Fitz Frames, already available in Brazil, wants your face printed into its glasses]
# If you’re a recent college graduate, you were given a quest to find the best pair of glasses.
#
# For the past year or so, free-market clothing brand Gabrielle Corbin has been traveling the country giving out fashion mini-tiques to people who stunk and stuttered, and Corbin says she was initially ignored — she received so many inquiries for the perfect pair of glasses she was able to reduce the size significantly — from companies within her immediate family.
# Now, 40 miles away in Brazil, Corbin is able to find customers online much the way she did back in the U.S.
# I met Corbin while researching better clothing brands for entrepreneurs to look after their own. After taking my first step on the startup planet, I’d like to Corbin be the first to offering a more reliable way to find the perfect pair of glasses for my business. I want to be the one to make that happen.
#
# [How about shipping your glasses to a country? By shipping it by air?]
# One area where the international market is at an all-time high is package making. The idea is that you send the item to a country and it comes back, checked off, and the next time you want to try its stuff, to its full potential.
# “The more stuff that somebody has, the more frustrating it is for the consumer.”
# All sorts of crazy stuff is happening with customs, so when I had the issue of missing a piece of equipment, I had to get it replaced. Then when I moved out of Atlanta, Georgia, I had a problem importing clothes from Brazil.”
# Withastreet Ltd, by the way, is launching a blockchain startup ecosystem …
# Venture Capital offers, or helps are, investingoras built on the company’s open-source blockchain technology are reaching very high floors of the company. We are joined today by co-founder Elsamadisi Shervin, who “creeped[led]​” is none other than the ‘crowdsourced[, disabilities analyst co-founder and CEO Roman Kreuzberg tweeted today]," Khunstein told me.
# Kreuzberg was responding to a question about why some open-source startups lose revenue as they continue to grow their teams. Khunstein, for his part, previously spent more than a decade working as an investment banker, and as a manager of cryptocurrency startups.
# In this latest round of funding, Kleiner offers up another reminder of the dangers of investing too much in unknowns. +++
# Also read:
# Bank of China to spend 10 x percent of GDP on renewable power generation
#
# Forbes ranks Brazil as the 20th largest economy after India and 23rd for the world for its beauty
#
# Binks make shoes that are lighter in material, have better reinforcement, make sensors that sense movement and are made with a protein that helps break down chemicals, startup Bay Area director Matthew Dussud tells TechCrunch.
# He’s right up there with him. Earlier this year, Chinese startup Weibo reported on its success using genetically engineered ingredients to make shoes, and followed that with a wave of funding in the first half of this year.
# “The beauty of Chinese manufacturing is that there’s no two factories are the same. There are no minimum wage, there are no infant and youth education systems, and there are some companies that stock animal proteins.”
# As more companies try to meet the companyhouse protein goals, the trend is for the company to come up with a better protein for its customers,” Kawasaki Endeavs director of research Brendan McNamara says. “The more companies try
#
# [900 | 541.39] loss=0.06 avg=0.06
# [901 | 541.89] loss=0.04 avg=0.06
# [902 | 542.38] loss=0.05 avg=0.06
# [903 | 542.87] loss=0.03 avg=0.06
# [904 | 543.36] loss=0.07 avg=0.06
# [905 | 543.86] loss=0.05 avg=0.06
# [906 | 544.35] loss=0.07 avg=0.06
# [907 | 544.84] loss=0.02 avg=0.06
# [908 | 545.33] loss=0.08 avg=0.06
# [909 | 545.83] loss=0.04 avg=0.06
# [910 | 546.31] loss=0.04 avg=0.06
# [911 | 546.81] loss=0.03 avg=0.06
# [912 | 547.30] loss=0.05 avg=0.06
# [913 | 547.80] loss=0.06 avg=0.06
# [914 | 548.29] loss=0.04 avg=0.06
# [915 | 548.78] loss=0.04 avg=0.06
# [916 | 549.27] loss=0.04 avg=0.06
# [917 | 549.76] loss=0.08 avg=0.06
# [918 | 550.25] loss=0.04 avg=0.06
# [919 | 550.74] loss=0.03 avg=0.06
# [920 | 551.23] loss=0.05 avg=0.06
# [921 | 551.72] loss=0.04 avg=0.06
# [922 | 552.22] loss=0.03 avg=0.06
# [923 | 552.71] loss=0.03 avg=0.06
# [924 | 553.20] loss=0.06 avg=0.06
# [925 | 553.69] loss=0.03 avg=0.05
# [926 | 554.18] loss=0.03 avg=0.05
# [927 | 554.67] loss=0.03 avg=0.05
# [928 | 555.16] loss=0.02 avg=0.05
# [929 | 555.66] loss=0.05 avg=0.05
# [930 | 556.15] loss=0.04 avg=0.05
# [931 | 556.65] loss=0.03 avg=0.05
# [932 | 557.14] loss=0.08 avg=0.05
# [933 | 557.63] loss=0.04 avg=0.05
# [934 | 558.12] loss=0.05 avg=0.05
# [935 | 558.61] loss=0.04 avg=0.05
# [936 | 559.10] loss=0.02 avg=0.05
# [937 | 559.59] loss=0.06 avg=0.05
# [938 | 560.09] loss=0.05 avg=0.05
# [939 | 560.58] loss=0.03 avg=0.05
# [940 | 561.07] loss=0.02 avg=0.05
# [941 | 561.56] loss=0.06 avg=0.05
# [942 | 562.05] loss=0.03 avg=0.05
# [943 | 562.55] loss=0.06 avg=0.05
# [944 | 563.04] loss=0.06 avg=0.05
# [945 | 563.54] loss=0.03 avg=0.05
# [946 | 564.03] loss=0.04 avg=0.05
# [947 | 564.52] loss=0.03 avg=0.05
# [948 | 565.01] loss=0.06 avg=0.05
# [949 | 565.50] loss=0.02 avg=0.05
# [950 | 565.99] loss=0.08 avg=0.05
# [951 | 566.48] loss=0.03 avg=0.05
# [952 | 566.97] loss=0.08 avg=0.05
# [953 | 567.46] loss=0.04 avg=0.05
# [954 | 567.95] loss=0.04 avg=0.05
# [955 | 568.44] loss=0.02 avg=0.05
# [956 | 568.93] loss=0.03 avg=0.05
# [957 | 569.42] loss=0.03 avg=0.05
# [958 | 569.90] loss=0.03 avg=0.05
# [959 | 570.39] loss=0.05 avg=0.05
# [960 | 570.88] loss=0.06 avg=0.05
# [961 | 571.37] loss=0.03 avg=0.05
# [962 | 571.86] loss=0.03 avg=0.05
# [963 | 572.36] loss=0.03 avg=0.05
# [964 | 572.85] loss=0.06 avg=0.05
# [965 | 573.34] loss=0.04 avg=0.05
# [966 | 573.84] loss=0.06 avg=0.05
# [967 | 574.33] loss=0.04 avg=0.05
# [968 | 574.82] loss=0.05 avg=0.05
# [969 | 575.31] loss=0.07 avg=0.05
# [970 | 575.81] loss=0.05 avg=0.05
# [971 | 576.30] loss=0.05 avg=0.05
# [972 | 576.79] loss=0.04 avg=0.05
# [973 | 577.28] loss=0.06 avg=0.05
# [974 | 577.77] loss=0.03 avg=0.05
# [975 | 578.26] loss=0.04 avg=0.05
# [976 | 578.75] loss=0.04 avg=0.05
# [977 | 579.24] loss=0.04 avg=0.05
# [978 | 579.74] loss=0.04 avg=0.05
# [979 | 580.23] loss=0.06 avg=0.05
# [980 | 580.72] loss=0.05 avg=0.05
# [981 | 581.21] loss=0.03 avg=0.05
# [982 | 581.70] loss=0.04 avg=0.05
# [983 | 582.19] loss=0.03 avg=0.05
# [984 | 582.68] loss=0.03 avg=0.05
# [985 | 583.17] loss=0.04 avg=0.05
# [986 | 583.66] loss=0.04 avg=0.05
# [987 | 584.15] loss=0.04 avg=0.05
# [988 | 584.64] loss=0.05 avg=0.05
# [989 | 585.13] loss=0.06 avg=0.05
# [990 | 585.63] loss=0.03 avg=0.05
# [991 | 586.12] loss=0.06 avg=0.05
# [992 | 586.61] loss=0.04 avg=0.05
# [993 | 587.10] loss=0.03 avg=0.05
# [994 | 587.59] loss=0.06 avg=0.05
# [995 | 588.08] loss=0.05 avg=0.05
# [996 | 588.57] loss=0.08 avg=0.05
# [997 | 589.06] loss=0.04 avg=0.05
# [998 | 589.55] loss=0.03 avg=0.05
# [999 | 590.04] loss=0.06 avg=0.05
# Saving checkpoint/run1/model-1000
# Generating samples...
# ======== SAMPLE 1 ========
# vs-“s recent acquisition of Truepill, a delivery startup that settled for the bottom of the Iowa drain for the best prices, according to data from Tradewind. “That’s a problem and one we intend to solve as we work to make sure that’s what Truepill was doing at Truepill better than possible, Donegan said in an email. “I want to thank you for your hard work in finding this deal.”
# Foundation Capital, Index Ventures, Social Capital, Box Group & Phillipines Capital  areors that are based in the U.K. and are by far the biggest investors, with  Twerking managing director Carmen Yulín Vardalos saying, “The London-based internet company’s success at home and abroad is due in large part to our London offices. We can’t be more at home in helping the world wide experts to process their data and make informed choices,” Yulín tells TechCrunch. “We are taking the next step in ­technology at the heart of us.”
# Founded in 2012 by Marco Maria Fernández, the company employs more than 100 people and has raised $197 million in loans and equity offerings, as well as a running surfeit of TigerCommuting.com, it’s co-working-stock and stock buybacks. After launching the first SVN virtual-prison network round, which failed again in June, Yulín says the company has since spent an additional $20 million on marketing and publicity.
# Foundation Capital is spending millions to bring Venezuela’s new Chávez Capital, or CCV, city to life, with a cost expected to be a $30 million investment. The company confirmed to TechCrunch that it has raised $20 million in venture funding, as well as a host of other noteworthy rewards, on top of raising $90 million in debt and equity funding raised over the summer.
# “What we are doing, spending tens of millions of dollars on marketing and publicity,” says Gabriel González, co-founder and CEO of CoruVentures, “comes as a huge relief. We didn’t have enough money to invest in a co-founder and a CEO that actually knows the country well. This means bringing co-founders and CEOs from around the world to Venezuela is really the size of my bank loans package. We donated $100 million to fund Chipotle, and since that deal was not easy, we are already working hard to pay the bills.”
# Huge thanks to Gennady Golos, Douglas Feynman, Michael Nason, Michael Nason Heine, Travis Anderton and Guillermo Pacheco for their help with the form and for taking the survey. The version of the C++ algorithms Yale created to algorithmfit campus facilities returned us this chart of the results:
# We can read between the lines and hope that by giving Chávez the lead in the city, the city will continue to support him.
# In other words, if you could give every student in Chávez a smartphone and they could make a super-prepared, online course that was developed in-person, before the Supreme Court's 2010 overhaul, today's mobile students won’t need to go to the Internet of Things to get their research projects monitored.
# That kind of self-reliance isn’t new. In fact, Narby Kochering, a senior director at human resources planning for Edmunds, the public relations firm, who was not involved in creating the survey, indicated that the company’s growth has been spurred by the desire to reduce foreclosures in the U.S. and Europe.
# So, too, are the student protests.
# “We want to help our student government ministers make sense of their lives,” said Kochering. “Incomes growth is driven by what’s most important expense — monthly fees. “That’s the big picture.”
# Responsible for streamlining student life advice, Holy Grail of the online education startup scene is a form of loan repayment assistance that combines an in-kind donation and a loan waiver. The student loan debt crisis is creating an economic trend. Inability to repay student loans causes young people to rely on credit cards to make ends meet and delay major life choices like investing in property, starting businesses and saving for retirement — things that many of us now are able to do solely online.
# Using AI, Holy Grail is tackling this economic disconnect by giving young people disposable income — usually known as the CPP or Consumer Price Index — to use to monitor their finances.
# In some ways, this is the face of affordable student loan debt: A common problem that college graduates have is that they owe more than they are saving for things like student loan repayments, or their savings actually restoring
#
# [1000 | 604.16] loss=0.07 avg=0.05
# [1001 | 604.65] loss=0.04 avg=0.05
# [1002 | 605.15] loss=0.07 avg=0.05
# [1003 | 605.64] loss=0.03 avg=0.05
# [1004 | 606.14] loss=0.04 avg=0.05
# [1005 | 606.63] loss=0.04 avg=0.05
# [1006 | 607.12] loss=0.03 avg=0.05
# [1007 | 607.61] loss=0.03 avg=0.05
# [1008 | 608.10] loss=0.05 avg=0.05
# [1009 | 608.60] loss=0.03 avg=0.05
# [1010 | 609.09] loss=0.04 avg=0.05
# [1011 | 609.59] loss=0.03 avg=0.05
# [1012 | 610.08] loss=0.03 avg=0.05
# [1013 | 610.58] loss=0.02 avg=0.05
# [1014 | 611.07] loss=0.06 avg=0.05
# [1015 | 611.56] loss=0.04 avg=0.05
# [1016 | 612.06] loss=0.05 avg=0.05
# [1017 | 612.55] loss=0.03 avg=0.05
# [1018 | 613.04] loss=0.04 avg=0.05
# [1019 | 613.54] loss=0.02 avg=0.05
# [1020 | 614.03] loss=0.03 avg=0.05
# [1021 | 614.52] loss=0.04 avg=0.05
# [1022 | 615.01] loss=0.03 avg=0.05
# [1023 | 615.51] loss=0.03 avg=0.05
# [1024 | 616.00] loss=0.05 avg=0.05
# [1025 | 616.50] loss=0.05 avg=0.05
# [1026 | 616.99] loss=0.03 avg=0.05
# [1027 | 617.48] loss=0.08 avg=0.05
# [1028 | 617.97] loss=0.04 avg=0.05
# [1029 | 618.47] loss=0.09 avg=0.05
# [1030 | 618.96] loss=0.04 avg=0.05
# [1031 | 619.45] loss=0.06 avg=0.05
# [1032 | 619.94] loss=0.05 avg=0.05
# [1033 | 620.43] loss=0.05 avg=0.05
# [1034 | 620.93] loss=0.03 avg=0.05
# [1035 | 621.42] loss=0.04 avg=0.05
# [1036 | 621.92] loss=0.05 avg=0.05
# [1037 | 622.41] loss=0.04 avg=0.05
# [1038 | 622.90] loss=0.04 avg=0.05
# [1039 | 623.40] loss=0.04 avg=0.05
# [1040 | 623.89] loss=0.02 avg=0.05
# [1041 | 624.38] loss=0.03 avg=0.05
# [1042 | 624.87] loss=0.04 avg=0.05
# [1043 | 625.37] loss=0.05 avg=0.05
# [1044 | 625.87] loss=0.04 avg=0.05
# [1045 | 626.36] loss=0.04 avg=0.05
# [1046 | 626.85] loss=0.03 avg=0.05
# [1047 | 627.34] loss=0.05 avg=0.05
# [1048 | 627.84] loss=0.01 avg=0.05
# [1049 | 628.33] loss=0.02 avg=0.05
# [1050 | 628.83] loss=0.04 avg=0.05
# [1051 | 629.31] loss=0.04 avg=0.05
# [1052 | 629.81] loss=0.03 avg=0.05
# [1053 | 630.30] loss=0.07 avg=0.05
# [1054 | 630.79] loss=0.04 avg=0.05
# [1055 | 631.29] loss=0.07 avg=0.05
# [1056 | 631.78] loss=0.03 avg=0.05
# [1057 | 632.27] loss=0.04 avg=0.05
# [1058 | 632.76] loss=0.02 avg=0.05
# [1059 | 633.26] loss=0.07 avg=0.05
# [1060 | 633.76] loss=0.03 avg=0.05
# [1061 | 634.25] loss=0.03 avg=0.05
# [1062 | 634.74] loss=0.10 avg=0.05
# [1063 | 635.23] loss=0.02 avg=0.05
# [1064 | 635.73] loss=0.04 avg=0.05
# [1065 | 636.22] loss=0.06 avg=0.05
# [1066 | 636.71] loss=0.03 avg=0.05
# [1067 | 637.20] loss=0.05 avg=0.05
# [1068 | 637.70] loss=0.02 avg=0.05
# [1069 | 638.19] loss=0.04 avg=0.05
# [1070 | 638.68] loss=0.04 avg=0.05
# [1071 | 639.18] loss=0.04 avg=0.05
# [1072 | 639.67] loss=0.03 avg=0.04
# interrupted
# Saving checkpoint/run1/model-1073
# ^C

# %% [markdown]
# Save our checkpoints to start training again later

# %%
# !cp -r /content/gpt-2/checkpoint/ /content/drive/My\ Drive/

# %% [markdown]
# Load your trained model for use in sampling below (117M or 345M)

# %%
# !cp -r /content/gpt-2/checkpoint/run1/* /content/gpt-2/models/117M/

# %%
# !cp -r /content/gpt-2/checkpoint/run1/* /content/gpt-2/models/345M/

# %% [markdown]
# Generate conditional samples from the model given a prompt you provide -  change top-k hyperparameter if desired (default is 40),  if you're using 345M, add "--model-name 345M"

# %%
# !python3 src/interactive_conditional_samples.py --top_k 40 --model_name "117M"
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0818 16:32:00.346473 140687501363072 deprecation_wrapper.py:119] From /content/gpt-2/src/model.py:147: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# W0818 16:32:00.433767 140687501363072 deprecation_wrapper.py:119] From src/interactive_conditional_samples.py:55: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-08-18 16:32:00.435408: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-08-18 16:32:00.476700: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-18 16:32:00.477113: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2019-08-18 16:32:00.477377: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-18 16:32:00.478517: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-08-18 16:32:00.479588: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2019-08-18 16:32:00.479899: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2019-08-18 16:32:00.481129: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2019-08-18 16:32:00.482092: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2019-08-18 16:32:00.484931: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-08-18 16:32:00.485077: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-18 16:32:00.485521: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-18 16:32:00.485866: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2019-08-18 16:32:00.490812: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-08-18 16:32:00.491030: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x226d480 executing computations on platform Host. Devices:
# 2019-08-18 16:32:00.491063: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-08-18 16:32:00.615391: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-18 16:32:00.615882: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x226cbc0 executing computations on platform CUDA. Devices:
# 2019-08-18 16:32:00.615909: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2019-08-18 16:32:00.616127: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-18 16:32:00.616491: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2019-08-18 16:32:00.616563: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-18 16:32:00.616588: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-08-18 16:32:00.616609: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2019-08-18 16:32:00.616628: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2019-08-18 16:32:00.616646: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2019-08-18 16:32:00.616663: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2019-08-18 16:32:00.616682: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-08-18 16:32:00.616771: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-18 16:32:00.617157: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-18 16:32:00.617491: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2019-08-18 16:32:00.617564: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-18 16:32:00.618472: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-08-18 16:32:00.618495: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2019-08-18 16:32:00.618509: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2019-08-18 16:32:00.618809: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-18 16:32:00.619202: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-18 16:32:00.619552: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:40] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-08-18 16:32:00.619594: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14202 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# W0818 16:32:00.620186 140687501363072 deprecation_wrapper.py:119] From src/interactive_conditional_samples.py:56: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0818 16:32:00.623176 140687501363072 deprecation_wrapper.py:119] From src/interactive_conditional_samples.py:58: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# W0818 16:32:00.626179 140687501363072 deprecation_wrapper.py:119] From /content/gpt-2/src/model.py:148: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0818 16:32:04.331856 140687501363072 deprecation.py:323] From /content/gpt-2/src/sample.py:65: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0818 16:32:04.345895 140687501363072 deprecation.py:323] From /content/gpt-2/src/sample.py:16: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0818 16:32:04.347408 140687501363072 deprecation.py:323] From /content/gpt-2/src/sample.py:70: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.random.categorical` instead.
# W0818 16:32:04.356406 140687501363072 deprecation_wrapper.py:119] From src/interactive_conditional_samples.py:66: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0818 16:32:04.472636 140687501363072 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Model prompt >>> smart home
# 2019-08-18 16:33:56.231779: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# ======================================== SAMPLE 1 ========================================
# ' is becoming increasingly commonplace, with a growing quantity reaching a high point this June. The market capitalization for such a device, now approaching $100M, is nothing to sneeze at, but it quickly evolved into a industry of its size.
# Earlier this year, San Francisco banned the city-owned air traffic control app T.S. (which has since been removed) — citing privacy violations — with an 8-by-14-foot (2.1-metre) blimp that it tumbled 700 metres (1,800m) and caused $20 million in property taxes to be refunded.
# Now, though, city officials are tackling a problem that has dogged their sincerest rollout of a highly effective but still-underutilized speed camera.
# The camera, called The Tech, is based in Auburn, Australia, and it operates for about $10 per month.
# SPONSORED
# Cam operators can pick from a variety of perspectives — from height to skin color — to take good-quality body position data, and upload it to a DropBox data warehouse in New York.
# The Tech takes measurements about an hour, analyzes it and sends it to the drop box, where the next layer of defense is measuring the moment at a point at which the garment stretches and contracts, sending vibrations along the garment.
# Machines that currently make the right stuff for the job are becoming outdated or nonexistent, so the techs of today are using thermography to measure the air pressure at a specific point in a garment. That air is then sent to be tested — and a verdict is made based on that measurement.
# Machines that usually make the right stuff for the job are no longer the tech industry is made of.
# The new CTO wants to build stuff that doesn’t need to be made. He wants to automate this type of research and development for himself and his family.
# “He wants to get this kind of data with less human effort” says Star.
# The family-owned company is raising $2.3 million in seed funding led by angel investor WeWork. The round is ongoing, but is also larger than expected for a company with a proven track record of shareholder value.
# Here’s how it works:
# With participation from existing investors, Turing Group, Tuesday’srey and Vietnam Development Co., it’s classed up operations expenses of at least 10% of outstanding shares. Under the solicitation process, shareholders can expect to be paid
# ================================================================================
# Model prompt >>> porgs
# ======================================== SAMPLE 1 ========================================
#  is a blockchain-focused startup that’s launching from Y Combinator. Its mission is to build the first decentralized data model infrastructure for data and analytics, scaling with it to a full-fledged data team. It’s made up of Y Combinator alumni—former Cisco chief executive officer Romain Leroy Patricet, former Microsoft chief executive officer Jose Ivalo Granados, Silicon Valley VCs DavidandUs VCs Y Combinator alumni include Angel Intelligence,  Ignite, Salesforce.ie, MongoDB, Red Hat, and Red Hat RedFest is due to take place this Saturday, August 11 (Sunday is YC’s Great Grand Opening) and run until Tuesday (Holiday).
# [Y Combinator-backed Narrator wants to become your monthly robo-advisor]
# In his latest venture, Narrator sees itself as a platform for the world of data. Problem is, much of the growth comes from the way in which workers’”s data is organized.
# To facilitate data movement,” Narrator”s policy is that customers and suppliers telephon­siate between the two approaches,” and datacenters can faces to mutually support one another. Funds are remitted to the Angel Investors Index, which is currently sitting at a four-year low.
# According to TechCrunch, Narrator”s valuation is in line with funding InVC  investors Inra Capital and Box Group ,” but weighing additional valuations would require placing high-quality analytics tools into every startup’s data centers. Thats where the Initialized Capital Y Combinator  investment opportunity hol”ific potential lies.
# [Image: Justin Sullivan/Getty Images]
#  aorb
#
# ‡ they’re Twitter bots,”
#
# Co-founders ” Tom Hertog and Michael Bowen’️​ are well-known for bringing big ideas to people’s ther”solving problems. But with delivery times becoming more frequent, it’s become increasingly difficult to know which customers are worth bothering with first.
# Now, that’s a problem and a solution.
# Here’s how it works:
# With a delivery company, you own the robo-advisor,” the startup says. The startup raises the costs of drivers, cameras, and the like, and provides them to its platform. Within seven days of being a market
# ================================================================================
# Model prompt >>> Frydgge
# ======================================== SAMPLE 1 ========================================
# vsVu4VyLmFrdpWVyaWF2VyMTA2xAd
#
# For those of you who are in the US only and want to buy candy, but are less likely likely in budget to eat organic or rely on animal protein, Rx “traces’ financials even more deeply. The platform provides users upload and retrieve financial data, including values for any given month, for free.
# Venture capitalists like to cite data structures that allow capitalists to streamline businesses rather than rely on external partners. But as more corporations adopt dataframes that promote best practices and align metrics with value, companies increasingly want to know how well their systems hold up, what are the risks and benefits of using different approaches, and how can they be optimized.
# One company that stands out is Lineagex  itself. Prior to Linex, this type of analysis was often performed on business data, but Path Research has been exploring how well existing companies will respond to new digital risks.
# As a recent co-signer of ClearValues, a company looking to improve customer service intelligence for digital payments, I was struck by how differently Silicon Valley approaches customer service — and why it can’t get away with treating customer service this way.
# First off, it’s worth noting that this is a new technology; a recent CIO’s latest success story was dealing with a data team that found that their customers did not meet their data quality standards. As a result, them and their team launched a company called ClearValues.‡
# “What’s a success story of launching a new technology that combines data and customer service insights? Well, by combining data and customer service, we’re able to create better customer service plans for new businesses.”
# Here’s how it works:
# With an investment of $, $, or BTC, anyone with the ability to download the newest version of Android — a Google Summer of Code accelerator freebie — can become a contributor to the company’s free arm.
# Within 24 hours of being a contributor, their subscription provides them with a digital token called a Google Wallet. Within seven days, users can earn Google Wallet tokens for participating in the subscription, as well as an additional 10% equity stake in the new startup.
# The service is currently available to pre-purchase, but the company says it’ll utilityfully pilot the feature into multi-productions starting in the next
# ================================================================================
# Model prompt >>> C-3PO
# ======================================== SAMPLE 1 ========================================
# .
# Machines that manage debt — whether it be online lending sources or utility bills — can be a time sensitive process. Traders build off of this debt model to create larger quantities of equity markets and equity futures commodities. But as the market for small businesses expands, so does the demand for fixed-term bonds.
# Banks are also using the fixed-term loan option on myBS Wealth, an 80-point growth platform, to sheets their customers' loans totaling at least 20%, according to Hettes. The platform provides loans with problable decimal points, where a power point can calculate the value of a stock, down from as high as $1,000.
# Loan companies that have used myBS to stock desks are fully booked, thanks to the robust startup process. From the waitlist optimization to the building of automated turnaround points, myBS helps companies turn around failed companies that quickly foot the bills.
# "When I first started, there was no analytics or model integration with the structure of the contracts or the way the investors were bidding," Hettes says. "Now that companies are able to break even and know how the money is spent, it reduces the need to think about things in terms of cash, right? It reduces the stress on the human hand for creating relationships and determining where the next step is for communication."
# Using machine learning to your advantage
# Hettes has also started with customers. "With a startup like Airbnb, there is a need to have a physical presence around the world to provide for his or her family, to community events and so forth," she says. "So, if a user were to bring their own device, and brought a device with them, they could bring their own device wherever they flew. But with Airbnb, there was no one spot in the house where people could bring their own device, and that was very frustrating for users. … [That] gave me pause. … The other thing I was trying to do was provide for my family. … If my husband brought his wife and four kids, and my three children brought a boy and a girl, my four-year-old son had to go through the process of changing his name to Ariel. That was a different kind of complication than having a name that was related to your child or your partner.
# Hettes cites a 2013 survey by the New York-based company Mobile Guidance that found 65 per cent of American women said having a name that was similar to their husband or partner was similar to the gender at
# ================================================================================
# Model prompt >>> D-O
# ======================================== SAMPLE 1 ========================================
# rem) is one of 11 co-founders to back Hacking In Action, and a native New Yorker, Gabriel Landesman. Their latest shot at a living taking the technology further afield is at the cutting-room floor, negotiating the next step in the evolution of the tech.
#
# [Y Combinator-backed Narrator is making a name for itself by bringing the tools of the customer]
# C-C-C- … most people start by giving the business a try, and then move on to all the startups they can think of in one place. Narrator is making that choice easy by bringing the tools of the customer at its disposal.
# “What”s happening in Narrator is very surprising to me.” By bringing the tools of the customer at Narrator”s disposal, Narrator is reducing the need to make these large-scale, engineering decisions that’s required in the engineering process of creating a product”.
# The goal is to become more of a customer journeyman, by making it easier for teams to identify and prioritize resources.” By reducing the engineering of the order of magnitude to make room for a new product, Narrator”s tool can be a smarter option for teams that have been prone to over-engineering in the past.
# “The biggest concern [customers have] is, ‘Okay, how do I make this greater marketplace better?” said Narrator. “The more choices a company has, the more difficult it is to make sense of very large data sets.”
# 东If we had to pick the biggest problem we wished we could fix, it would be this gigantic data crisis that exists with so much data at once.”
# “The biggest concern [customers have] is, ‘Okay, how do I make this greater marketplace better?”
# “The biggest problem is, sometimes the solution is actually more effective than the reality.”
# Narrator follows a long line of Y Combinator graduates that built startups catering to other startups, as the accelerator becomes more of a SaaS incubator of sorts. PagerDuty and Docker proved that YC companies could build with a strong focus on other YC companies. Brex, a recent YC grad that issues credit cards to entrepreneurs, has leveraged the same startup-focused model for big-time success.
# “Why not build a company to make something that
# ================================================================================
# Model prompt >>> Chewbacca
# ======================================== SAMPLE 1 ========================================
# ’s newest venture, which hasn’t scaled to the consumer level yet but is currently fending off venture capital,”s structure’s[.] is similar to the early stages of Gudrun’s Star. He is creating his own optimized engine that will be able to run the tests built using Gudrun’s tests data and analyze them to guide future optimizations.
# Star isn’t the first startup to use the normal tools at its disposal to its advantage. Over at Oh My! before it, Venturesha and co., the startup created the’obviously” start-up’s “largest acquisition” after market cap. While their acquisition meets or beats out all the previous VC acquisitions, they follow the same model.
# “They run the experiments.” As it turns out, the experiments are worked out.
# Before deciding to buy Oh My!, Binks employees wrote a 3,000-word binder detailing how much they’d like the business and how broadly it’s run. The company’s binder contains a mix of the actual stock and the performance price of some of the company’s newest products, according to Star.
# Binks’ latest product line-up includes:
#
# “Birth control
#
# “Trim cream
#
# “Glace serum
#
# “Eye powder
#
# “Glasses
#
# Binks relies on a combination of Google Cardboard and A* to manage subscription data — something that many customers struggle with’trees are makeovers and functional layout more important than functional beauty.
#
# Binks also employs a mix of open data and contract software to manage with more robust analytics.
# Binks employs a combination of open data and contract software to manage with more robust analytics. “Binks uses an existing model and updates it to use new space’t to its advantage, BinksCEO Frankel said.
# Binks uses an existing model and updates it to use new space to its advantage —“by using the latest technology, pros at Bitscan’s Path to Airstream can give their startups a shot at scaling. They can also the vernier [AA] series of software packages, which typically cost $5 million to $10 million and can be ordered in early 2017.
# Binks uses the same software stack as their vernis [AAC] software, but relies on
# ================================================================================
# Model prompt >>> ewok
# ======================================== SAMPLE 1 ========================================
# , the only other Korean-based data platform to be certified in compliance with the’騙AFTA/Getty Images  standards, today declined to comment on its sustainability goals.
# But the South Korean startup seems committed to replicating its business model, rather than relying on third-party suppliers. The founders of Idea and Y Combinator  use the same production chain and logistics infrastructure to partner with existing manufacturers, saving customers and shareholders a host of headaches.
# “We try to provide the most efficient process technology, but we also believe in bringing the next level by investing in the best research and development platform in the industry to deliver. Unlocking the latent power of our customers through a single platform’ is how An-Earthy Brewing and The Forerunner Solutions “ve found the Holy Grail.
# “How can people no longer live with their pasts and want to rethink them? By investing in a better future and investing in the right people, that’s the goal:” said Lee Young, Y Combinator’s senior vice president of innovation.
# Founded in 2012 by Justin Lee,​ the co-founder and CEO of Lee Young Minh Optical,​ the company’s Tomlin time means no more waiting around for your next dress order. The solution is something that can be worn anytime, anywhere, anytime, and with little or no additional planning, Lee explained, ‪Everything from the furniture to the food to the powerpoint presentation is done directly by the user.”
# Left: Justin Lee taking a break from taking the lead in the investment. Right: The world’s first powerpoint presentation taking inspiration from the candidate applications
# Using the power of your email account, Lee said, users can take a look at pictures of themselves to see what works and what doesn’t work, and see what their Foldable Presentation Presentation looks like. The user can also upload their own presentation screenshot, making it easy to monitor progress
# Users can link their laptop to the instance and connect to Google Cloud Storage, where the user can manage their data storage
# Users can also upload an online plan details and shipping date
# The user experience is the same as it was last year, with the product initially only available in English. A search for 'Foldable Land of the Geek' yields results in favor of the more common,,,,, results are directed at people with bigger purses.
# Foldable Land was started as a place
# ================================================================================
# Model prompt >>> Nikol Pashinyan
# ======================================== SAMPLE 1 ========================================
# , 26; Adam Yurchuk, 12, take off and burn with them
# Although it may seem like an early technology beta, Li's invention is only the latest in a long line of crowdfunding platforms that deliver. Chances are you and your family will also be wearing cryptocurrencies into your monthly financial calculations, too.
# In addition to being a better way to invest,” Tesfaye’s bet is that it’s in encouraging the adoption of digital currencies,” as long as they’re tied to their issuance.”
#
# [Dostavista, the ‘crowdsourced'’ brainstrust] team says that their approach’s adopting from crypto-currency Bitcoin’s creation principles — that of Bitcoin ATM/money order scams — is sustainable.
# As a fresh face to the payment industry, they hope that the attention they get from busysees will encourage more people to become involved.
#
# [Well-reviewed] XRP startup YChangers is set to launch a few weeks before the New York Stock Exchange — and launch with a bang —’ its flagship. YC grad student Corbin Hewitt says the company took a risk by introducing genetically engineered (GE) versions of the drug Heptav,  STI and bromo,  STev’s and nanoparticles to the company’s product.”
# The plan? Produce an xylem — or battery, semiconductor or chip manufacturer’s name falls under that umbrella.”
# “The xylem will be made from xylem, a plant’s toxin. “It will be made from the xylem itself,” says co-founder and director of engineering Star, Jose Maria de Oliveira.
# “The xylem will be made from 3D-printed electrodes,” he says. “The xylem should work really, really, really, really, really well.”
#
# [Dostavista’s student Fedor Indutny is another 'sophomore first' type']
# Dostavista is a new cryptocurrency-focused startup founded by Indian-American student Fedor Indutny at the end of June. The startup, which has raised $2 million in seed funding, is seeking to make altcoins more accessible and affordable.
# “We are trying to make it easier for people to find good resources for
# ================================================================================
# Model prompt >>> Melqonyan
# ======================================== SAMPLE 1 ========================================
#  launched with the goal of empowering women to easily create custom clothing for men and included multiple sizes and styles approved by the gal.
# Khan’s fresh garment line is made from scratch using the’foundry’s templates and”comes with a protective microfiber sleeve that helps prevent the ーfrom fleeving’s face from leaving’s clothing.
# “The garment comes with a tracking number, which can be turned into a funding bit by customers.”
# To date the company has raised $18 million in funding in one go, taking its valuation to $1 billion. New investors include Virgin Group and Men’s Tech Capital.
# A former engineering assistant at Microsoft, Masai has also backed up his data model to the company’s prototype.
# “The goal is to provide easier compliance than current systems,” said Khan. “By providing a set of trusted e-wallets,” which are checked by an on-site data engineer, Masai’s trying to’ get his or her business’s programs back on track.
# surprised that most customers don’t carry any physical tracking data, but there’s a’ concern that its systems might not be responsive enough if there’s a fire or burgladee trying to break in. also hit respond to quickly — but with greater urgency — to ensure all venues are up to code.
#
# read moreDozens Of Hotels Are Responding to Hotels That Don’t Have Bluetooth Low Energy BinksPower Ventures, backed by American Express, is providing Bluetooth Low Energy Binks tech for every hotel in America. The company tells the story of its experience with 16 of our Platinum Members and is’t the first hotel not to include it. .
# At OurRoom, we’re producing custom batteries that last for years. We use them to charge and unload things,'' says Star. We use them to cool clothing, carry cameras, and more. We roll those cameras every time, and then we reboot the machine to take new batteries. We’re doing it all with Elon Musk’s company. Our first model, a tiny Rider 2D, has since gone on to become our all-time’favorite pilot. Rider 2 sees a bodysnathered Norwegian boy named Carl try to land a new life outside of the comfort of his hometown. His goal is to become
# ================================================================================
# Model prompt >>> porglet
# ======================================== SAMPLE 1 ========================================
#  3D glasses are becoming ubiquitous, but the device is also made with strict safety protocols in mind.
# "Every time you step inside, you are sending a signal to the outside world that moves according to their body shape — their type of water, how strong their drafts are — but the only signal coming from inside your glasses is the shape of your head — it doesn’t represent how you will perceive the world —” Shysh says.
# In some ways, the new technology — if anything might ease the burden of maintaining a facial-scanning app. If nothing else, using technology to automate a lot of the very tedious things that technology would do well, like calculating HazeltineAnchords and Harmonitarian scales,” theorizes StarTech co-founder and CTO Hao Ching.
# [Lumineye can recognize humans as well as they are trying to learn to navigate mixed martial arts ropes]
# Hoping to hire 100 more people before the year is up, Lumineye is a new mixed martial arts (MISV) device that humans use to judge the physicality of the room combatants move around. The hope is that by giving fighters more room to manoeuvre their weapons, they’d be able to more easily identify hostile crowds and avoid costly counterattacks.
# All fighters in the device react identically to where a strike is delivered, so it’s unrealistic to conclude that all a fighter is is isslespan is due to some small flaw in the device.
# “The thing about [hand-helds of] all the different brands of batteries is, if you had a button on the other end of the device, you could pull it and it could do what you want with the power, but if you put a button on the other end and then the device is pushed up against the tabletop, you can’t do that. The only way that your battery will work is if the device is raised up and pulled down, and that raises your chance of an an an an an an an an an an an an an an an an an an a problem.”
# One option the team has is that the device be turned off entirely, so that it’s possible to turn the on/off functionality of the device on its own. The only caveat is that the device should vibrate periodically, which could damage if tampered with.
# CraftWorks’ robotic arm is made from a composite of polycarbonate and
# ================================================================================
# Model prompt >>>

# %% [markdown]
# To check flag descriptions, use:

# %%
# !python3 src/interactive_conditional_samples.py -- --help

# %% [markdown]
# Generate unconditional samples from the model,  if you're using 345M, add "--model-name 345M"

# %%
# !python3 src/generate_unconditional_samples.py --model_name "345M" | tee /tmp/samples

# %% [markdown]
# To check flag descriptions, use:

# %%
# !python3 src/generate_unconditional_samples.py -- --help
